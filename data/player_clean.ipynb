# %% [markdown]
# # Fantasy Statbook
# ## Player Data Setup

# %%
import pandas as pd
import glob

# %%
players = {
    'name': [],
    'player_code': []
}

path = os.getcwd()+'\\data\\yearly'

# read all the files with extension .csv
filenames = glob.glob(path + "\*.csv")

c = 100
for file in filenames:
    df = pd.read_csv(file)
    unique_players = df['Player'].unique().tolist()

    for player in unique_players:
        if player not in players['name']:
            players['name'].append(player)
            #players['years_played'].append(i)
            players['player_code'].append(c)
            c+=1
    
df_players = pd.DataFrame(players)
df_players
#df_players.to_csv('players.csv')
# Out:
#                   name  player_code
# 0          Ron Johnson          100
# 1          Dick Gordon          101
# 2      Gene Washington          102
# 3        Gary Garrison          103
# 4       MacArthur Lane          104
# ...                ...          ...
# 6178    Juwann Winfree         6278
# 6179       Greg Dortch         6279
# 6180  Darrius Shepherd         6280
# 6181   Jarrett Stidham         6281
# 6182    Michael Walker         6282
#
# [6183 rows x 2 columns]

# %%
df_all = pd.DataFrame(columns=['Unnamed: 0', 'player_code', 'year', 'Player', 'Tm', 'Pos', 'Age', 'G', 'GS', 'Cmp', 'Att',
       'Yds', 'Int', 'Att.1', 'Yds.1', 'Tgt', 'Rec', 'Yds.2', 'Y/R', 'Fumbles',
       'FumblesLost', 'PassingYds', 'PassingTD', 'PassingAtt', 'RushingYds',
       'RushingTD', 'RushingAtt', 'ReceivingYds', 'ReceivingTD',
       'FantasyPoints'])

for file in filenames:
    year = file.replace(os.getcwd()+'\\data\\yearly\\', '')
    year = year.replace('.csv', '')
    df = pd.read_csv(file)
    
    print(year)
    codes = []
    years = []
    for index, row in df.iterrows():
        #codes.append(players.get(row['Player']))
        df_s = df_players.loc[df_players['name'] == row['Player']]
        #print(int(df_s.iloc[0]['player_code']))
        codes.append(int(df_s.iloc[0]['player_code']))
        years.append(year)
    df['player_code'] = codes
    df['year'] = year
    #print(df.columns)
    df_all = df_all.append(df)
# Out:
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019

# %%
df_all
#df_all.drop(columns='Unnamed: 0')
df_all.to_csv('allyears.csv')
